# %%
# %matplotlib inline
import matplotlib 
# %matplotlib inline
matplotlib.rc('xtick', labelsize=8) 
matplotlib.rc('ytick', labelsize=8)
#matplotlib.rc('mathtext', fontset='stix')
matplotlib.rcParams['font.size'] = 8
matplotlib.rcParams['axes.titlesize'] = 10
matplotlib.rcParams['figure.dpi'] = 300
matplotlib.rcParams['lines.linewidth'] = 1

import matplotlib.pyplot as plt
import numpy as np
import sys, os
sys.path.append('./rayleigh/plot')
from rayleigh_diagnostics import Shell_Slices
from matplotlib import ticker
from matplotlib import colors
from mpl_toolkits.basemap import Basemap, addcyclic
from common import get_widest_range_file, strip_dirname
from sslice_util import plot_ortho, units, labels, var_indices, cbar_axes_from_area, rms
from binormalized_cbar import MidpointNormalize

# Get the run directory on which to perform the analysis
dir3 = '/nobackup/lmatilsk/rayleigh/n3_movie_4M'
radatadir = dir3 + '/Shell_Slices/'
first_iter = 4200050
step_iter = 1150

# Directory to save plots
datadir = dir3 + '/data/'
plotdir = dir3 + '/plots/'

if not os.path.isdir(plotdir):
    os.makedirs(plotdir)

# Get grid info
rr,tt,cost,sint,rr_depth,ri,ro,d = np.load(datadir + 'grid_info.npy')
nt, nr = len(tt), len(rr)
nphi = 2*nt
cost_nd = cost.reshape((1, nt))
sint_nd = sint.reshape((1, nt))
phi = np.arange(0, 2*np.pi, 2*np.pi/nphi)
lats = 90 - tt*180/np.pi 
lons = phi*180/np.pi - 180
# Out:
# /nobackupp2/lmatilsk/rayleigh/plot/sslice_util.py:2: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/home1/lmatilsk/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home1/lmatilsk/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home1/lmatilsk/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home1/lmatilsk/anaconda3/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home1/lmatilsk/anaconda3/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 478, in start
#     self.io_loop.start()
#   File "/home1/lmatilsk/anaconda3/lib/python3.6/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/home1/lmatilsk/anaconda3/lib/python3.6/site-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/home1/lmatilsk/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home1/lmatilsk/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/home1/lmatilsk/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home1/lmatilsk/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/home1/lmatilsk/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home1/lmatilsk/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home1/lmatilsk/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home1/lmatilsk/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/home1/lmatilsk/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home1/lmatilsk/anaconda3/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home1/lmatilsk/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2728, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home1/lmatilsk/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2850, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home1/lmatilsk/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2910, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-c9bdfe9703c8>", line 3, in <module>
#     get_ipython().run_line_magic('matplotlib', 'inline')
#   File "/home1/lmatilsk/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2095, in run_line_magic
#     result = fn(*args,**kwargs)
#   File "<decorator-gen-107>", line 2, in matplotlib
#   File "/home1/lmatilsk/anaconda3/lib/python3.6/site-packages/IPython/core/magic.py", line 187, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#   File "/home1/lmatilsk/anaconda3/lib/python3.6/site-packages/IPython/core/magics/pylab.py", line 99, in matplotlib
#     gui, backend = self.shell.enable_matplotlib(args.gui)
#   File "/home1/lmatilsk/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2978, in enable_matplotlib
#     pt.activate_matplotlib(backend)
#   File "/home1/lmatilsk/anaconda3/lib/python3.6/site-packages/IPython/core/pylabtools.py", line 308, in activate_matplotlib
#     matplotlib.pyplot.switch_backend(backend)
#   File "/home1/lmatilsk/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py", line 231, in switch_backend
#     matplotlib.use(newbackend, warn=False, force=True)
#   File "/home1/lmatilsk/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py", line 1410, in use
#     reload(sys.modules['matplotlib.backends'])
#   File "/home1/lmatilsk/anaconda3/lib/python3.6/importlib/__init__.py", line 166, in reload
#     _bootstrap._exec(spec, module)
#   File "/home1/lmatilsk/anaconda3/lib/python3.6/site-packages/matplotlib/backends/__init__.py", line 16, in <module>
#     line for line in traceback.format_stack()
#
#
#   mpl.use('Agg')

# %%
# Set dimensions/location of patch to plot 
delta_lat = 40
delta_lon = 40
lon0 = 0
lat0 = 0

ith1, ith2 = np.argmin(np.abs(lats - (lat0 - delta_lat/2))),\
    np.argmin(np.abs(lats - (lat0 + delta_lat/2)))

iph1, iph2 = np.argmin(np.abs(lons - (lon0 - delta_lon/2))),\
    np.argmin(np.abs(lons - (lon0 + delta_lon/2)))
    
xtickvals = [lon0 - delta_lon/2, lon0 - delta_lon/4, lon0, lon0 + delta_lon/4, lon0 + delta_lon/2]
ytickvals = [lat0 - delta_lat/2, lon0 - delta_lat/4, lat0, lat0 + delta_lat/4, lat0 + delta_lat/2]

lonvals = lons[iph1:iph2]
latvals = lats[ith1:ith2]
llons, llats = np.meshgrid(lonvals, latvals, indexing='ij')

# %%
plt.plot(lonvals)

# %%
plt.plot(latvals)

# %%
Om0=7.8e-6
P = 2*np.pi/Om0
P/7/100
# Out:
# 1150.766539776481

# %%
iterr = first_iter
print ('Reading ' + radatadir + str(iterr).zfill(8) + ' ...')
a1 = Shell_Slices(radatadir + str(iterr).zfill(8), '')

iterr = first_iter + step_iter
print ('Reading ' + radatadir + str(iterr).zfill(8) + ' ...')
a2 = Shell_Slices(radatadir + str(iterr).zfill(8), '')

iterr = first_iter + 2*step_iter
print ('Reading ' + radatadir + str(iterr).zfill(8) + ' ...')
a3 = Shell_Slices(radatadir + str(iterr).zfill(8), '')

iterr = first_iter + 3*step_iter
print ('Reading ' + radatadir + str(iterr).zfill(8) + ' ...')
a4 = Shell_Slices(radatadir + str(iterr).zfill(8), '')

iterr = first_iter + 4*step_iter
print ('Reading ' + radatadir + str(iterr).zfill(8) + ' ...')
a5 = Shell_Slices(radatadir + str(iterr).zfill(8), '')

iterr = first_iter + 5*step_iter
print ('Reading ' + radatadir + str(iterr).zfill(8) + ' ...')
a6 = Shell_Slices(radatadir + str(iterr).zfill(8), '')

iterr = first_iter + 6*step_iter
print ('Reading ' + radatadir + str(iterr).zfill(8) + ' ...')
a7 = Shell_Slices(radatadir + str(iterr).zfill(8), '')

iterr = first_iter + 7*step_iter
print ('Reading ' + radatadir + str(iterr).zfill(8) + ' ...')
a8 = Shell_Slices(radatadir + str(iterr).zfill(8), '')
# Out:
# Reading /nobackup/lmatilsk/rayleigh/n3_movie_4M/Shell_Slices/04200050 ...
# Reading /nobackup/lmatilsk/rayleigh/n3_movie_4M/Shell_Slices/04201200 ...
# Reading /nobackup/lmatilsk/rayleigh/n3_movie_4M/Shell_Slices/04202350 ...
# Reading /nobackup/lmatilsk/rayleigh/n3_movie_4M/Shell_Slices/04203500 ...
# Reading /nobackup/lmatilsk/rayleigh/n3_movie_4M/Shell_Slices/04204650 ...
# Reading /nobackup/lmatilsk/rayleigh/n3_movie_4M/Shell_Slices/04205800 ...
# Reading /nobackup/lmatilsk/rayleigh/n3_movie_4M/Shell_Slices/04206950 ...
# Reading /nobackup/lmatilsk/rayleigh/n3_movie_4M/Shell_Slices/04208100 ...

# %%
# Set up figure dimensions parameters from scratch
fig_width_inches = 7.25
margin_middle_inches_x = 1/4
margin_middle_inches_y = 1/8
margin_bottom_inches = 3/8
margin_top_inches = 1/8
margin_left_inches = 1/2
cbar_area_inches = 3/4
npatches = 4
subplot_width_inches = (fig_width_inches - margin_left_inches - (npatches-1)*margin_middle_inches_x - cbar_area_inches)/npatches
subplot_height_inches = subplot_width_inches*delta_lat/delta_lon
fig_height_inches = margin_bottom_inches + 2*subplot_height_inches + margin_middle_inches_y + margin_top_inches
fig_aspect = fig_height_inches/fig_width_inches

margin_middle_x = margin_middle_inches_x/fig_width_inches
margin_middle_y = margin_middle_inches_y/fig_height_inches
margin_top = margin_top_inches/fig_height_inches
margin_bottom = margin_bottom_inches/fig_height_inches
margin_left = margin_left_inches/fig_width_inches
cbar_area = cbar_area_inches/fig_width_inches
subplot_width = subplot_width_inches/fig_width_inches
subplot_height = subplot_height_inches/fig_height_inches

# %%
# Find where 5% depth is
(ro - a8.radius)/d
# Out:
# array([0.05062893, 0.24821185, 0.49386377])

# %%
# Plot 5% depth
idepth3 = 0 

# set up colorbar axes
cbar_aspect = 20
cbar_area_left = margin_left + 4*(subplot_width) + 3*margin_middle_x
cbar_area_bottom = margin_bottom
cbar_area_width = cbar_area
cbar_area_height = 1 - margin_top - margin_bottom
cbar_area_centerx = cbar_area_left + cbar_area_width/2
cbar_area_centery = cbar_area_bottom + cbar_area_height/2
cbar_height = 0.5*cbar_area_height
cbar_width = cbar_height/cbar_aspect*fig_aspect
cbar_left = cbar_area_left + 0.25*cbar_area_width - cbar_width/2
cbar_bottom = cbar_area_centery - cbar_height/2

fs = 10
ls = 8

# %%
# How much does the differential rotation advect the flow every 1150 time steps?
# dunno why the hell this isn't working! Just do it manually
vavg_file = get_widest_range_file(datadir, 'vavg')

# Get the average velocities
vr_av, vt_av, vp_av = np.load(datadir + vavg_file)
vr_av /= 100; vt_av /= 100; vp_av /= 100

# average vphi over +/- 20 degrees
tt_lat = 90 - tt*180/np.pi
it1, it2 = np.argmin(np.abs(tt_lat + 20)), np.argmin(np.abs(tt_lat - 20))
vp_low = np.mean(vp_av[it1:it2+1, :], axis=0)
ir0 = a1.inds[idepth3]
vp0 = vp_low[ir0]
vp0
# Out:
# 359.8368346658882

# %%
delta_t = 100*1150 # time between patches in seconds
delta_rphi = delta_t*vp0 # advection of patches in meters
r0 = a3.radius[idepth3]/100 # location of 5% depth in meters
delta_phi_deflection = delta_rphi/r0
delta_phi_deflection_deg = delta_phi_deflection*180/np.pi
delta_phi_deflection_deg
# Out:
# 3.6444379923875987

# %%
# Compare this amount to the resolution
dphi_deg = 360/nphi
dphi_deg
# Out:
# 0.234375

# %%
my_min, my_max = -150, 150
fig = plt.figure(figsize=(fig_width_inches, fig_height_inches))
ax1 = fig.add_axes((margin_left, margin_bottom + subplot_height + margin_middle_y, subplot_width, subplot_height))
ax2 = fig.add_axes((margin_left + subplot_width + margin_middle_x, margin_bottom + subplot_height + margin_middle_y, subplot_width, subplot_height))
ax3 = fig.add_axes((margin_left + 2*(subplot_width + margin_middle_x), margin_bottom + subplot_height + margin_middle_y, subplot_width, subplot_height))
ax4 = fig.add_axes((margin_left + 3*(subplot_width + margin_middle_x), margin_bottom + subplot_height + margin_middle_y, subplot_width, subplot_height))

ax5 = fig.add_axes((margin_left, margin_bottom, subplot_width, subplot_height))
ax6 = fig.add_axes((margin_left + subplot_width + margin_middle_x, margin_bottom, subplot_width, subplot_height))
ax7 = fig.add_axes((margin_left + 2*(subplot_width + margin_middle_x), margin_bottom, subplot_width, subplot_height))
ax8 = fig.add_axes((margin_left + 3*(subplot_width + margin_middle_x), margin_bottom, subplot_width, subplot_height))

cbaxes = fig.add_axes([cbar_left, cbar_bottom, cbar_width, cbar_height])

t1 = a1.time[0]
vr_slice = a1.vals[:, :, idepth3, a1.lut[1], 0]/100
#std_plus = rms(vr_slice[np.where(vr_slice>0)])
#std_minus = rms(vr_slice[np.where(vr_slice<0)])
#my_min, my_max = -3*std_minus, 3*std_plus 
lon0 = 0
iph1, iph2 = np.argmin(np.abs(lons - (lon0 - delta_lon/2))),\
    np.argmin(np.abs(lons - (lon0 + delta_lon/2)))
lonvals = lons[iph1:iph2] - lon0 # Always show -20 to 20 deg. lon but SAY we're in the D.R. frame
llons, llats = np.meshgrid(lonvals, latvals, indexing='ij')

patch = vr_slice[iph1:iph2, ith1:ith2]
plt.sca(ax1)
plt.pcolormesh(llons, llats, patch, cmap=plt.cm.RdYlBu_r, vmin=my_min, vmax=my_max, norm=MidpointNormalize(0))
lw = 0.5
plt.plot(lonvals, np.zeros_like(lonvals), 'k', linewidth=lw)
plt.plot(np.zeros_like(latvals), latvals, 'k', linewidth=lw)
# Get ticks everywhere
plt.minorticks_on()
plt.tick_params(top=True, right=True, direction='in', which='both')
plt.text(-7, 0, 'A', fontsize=ls,\
        horizontalalignment='center', verticalalignment='center')
plt.text(-16, 4, r'$\rm{A}^\prime$', fontsize=ls,\
        horizontalalignment='center', verticalalignment='center')
plt.text(10, -4, 'B', fontsize=ls,\
        horizontalalignment='center', verticalalignment='center')
plt.gca().get_xaxis().set_ticks(xtickvals)
plt.gca().get_yaxis().set_ticks(ytickvals)
#plt.xlabel('longitude (degrees)', fontsize=fs)
#plt.ylabel('latitude (degrees)', fontsize=fs)

t2 = a2.time[0]
vr_slice = a2.vals[:, :, idepth3, a2.lut[1], 0]/100

lon0 = delta_phi_deflection_deg
iph1, iph2 = np.argmin(np.abs(lons - (lon0 - delta_lon/2))),\
    np.argmin(np.abs(lons - (lon0 + delta_lon/2)))
lonvals = lons[iph1:iph2] - lon0
llons, llats = np.meshgrid(lonvals, latvals, indexing='ij')

patch = vr_slice[iph1:iph2, ith1:ith2]
plt.sca(ax2)
plt.pcolormesh(llons, llats, patch, cmap=plt.cm.RdYlBu_r, vmin=my_min, vmax=my_max, norm=MidpointNormalize(0))
plt.plot(lonvals, np.zeros_like(lonvals), 'k', linewidth=lw)
plt.plot(np.zeros_like(latvals), latvals, 'k', linewidth=lw)
# Get ticks everywhere
plt.minorticks_on()
plt.tick_params(top=True, right=True, direction='in', which='both')
plt.text(-6, 0, 'A', fontsize=ls,\
        horizontalalignment='center', verticalalignment='center')
plt.text(-15, 4, r'$\rm{A}^\prime$', fontsize=ls,\
        horizontalalignment='center', verticalalignment='center')
plt.text(10, -4, 'B', fontsize=ls,\
        horizontalalignment='center', verticalalignment='center')
plt.gca().get_xaxis().set_ticks(xtickvals)
plt.gca().get_yaxis().set_ticks(ytickvals)
#plt.xlabel('longitude (degrees)', fontsize=fs)

t3 = a3.time[0]
vr_slice = a3.vals[:, :, idepth3, a3.lut[1], 0]/100

lon0 = 2*delta_phi_deflection_deg
iph1, iph2 = np.argmin(np.abs(lons - (lon0 - delta_lon/2))),\
    np.argmin(np.abs(lons - (lon0 + delta_lon/2)))
iph1, iph2 = np.argmin(np.abs(lons - (lon0 - delta_lon/2))),\
    np.argmin(np.abs(lons - (lon0 + delta_lon/2)))
lonvals = lons[iph1:iph2] - lon0
llons, llats = np.meshgrid(lonvals, latvals, indexing='ij')

patch = vr_slice[iph1:iph2, ith1:ith2]
plt.sca(ax3)
plt.pcolormesh(llons, llats, patch, cmap=plt.cm.RdYlBu_r, vmin=my_min, vmax=my_max, norm=MidpointNormalize(0))
plt.plot(lonvals, np.zeros_like(lonvals), 'k', linewidth=lw)
plt.plot(np.zeros_like(latvals), latvals, 'k', linewidth=lw)
# Get ticks everywhere
plt.minorticks_on()
plt.tick_params(top=True, right=True, direction='in', which='both')
plt.text(-6, 0, 'A', fontsize=ls,\
        horizontalalignment='center', verticalalignment='center')
plt.text(10, -4, 'B', fontsize=ls,\
        horizontalalignment='center', verticalalignment='center')
plt.gca().get_xaxis().set_ticks(xtickvals)
plt.gca().get_yaxis().set_ticks(ytickvals)
#plt.xlabel('longitude (degrees)', fontsize=fs)

t4 = a4.time[0]
vr_slice = a4.vals[:, :, idepth3, a4.lut[1], 0]/100

lon0 = 3*delta_phi_deflection_deg
iph1, iph2 = np.argmin(np.abs(lons - (lon0 - delta_lon/2))),\
    np.argmin(np.abs(lons - (lon0 + delta_lon/2)))
iph1, iph2 = np.argmin(np.abs(lons - (lon0 - delta_lon/2))),\
    np.argmin(np.abs(lons - (lon0 + delta_lon/2)))
lonvals = lons[iph1:iph2] - lon0
llons, llats = np.meshgrid(lonvals, latvals, indexing='ij')

patch = vr_slice[iph1:iph2, ith1:ith2]
plt.sca(ax4)
plt.pcolormesh(llons, llats, patch, cmap=plt.cm.RdYlBu_r, vmin=my_min, vmax=my_max, norm=MidpointNormalize(0))
plt.plot(lonvals, np.zeros_like(lonvals), 'k', linewidth=lw)
plt.plot(np.zeros_like(latvals), latvals, 'k', linewidth=lw)
# Get ticks everywhere
plt.minorticks_on()
plt.tick_params(top=True, right=True, direction='in', which='both')
plt.text(-6, 0, 'A', fontsize=ls,\
        horizontalalignment='center', verticalalignment='center')
plt.text(9, -4, 'B', fontsize=ls,\
        horizontalalignment='center', verticalalignment='center')
plt.gca().get_xaxis().set_ticks(xtickvals)
plt.gca().get_yaxis().set_ticks(ytickvals)
#plt.xlabel('longitude (degrees)', fontsize=fs)

t5 = a5.time[0]
vr_slice = a5.vals[:, :, idepth3, a5.lut[1], 0]/100

lon0 = 4*delta_phi_deflection_deg
iph1, iph2 = np.argmin(np.abs(lons - (lon0 - delta_lon/2))),\
    np.argmin(np.abs(lons - (lon0 + delta_lon/2)))
iph1, iph2 = np.argmin(np.abs(lons - (lon0 - delta_lon/2))),\
    np.argmin(np.abs(lons - (lon0 + delta_lon/2)))
lonvals = lons[iph1:iph2] - lon0
llons, llats = np.meshgrid(lonvals, latvals, indexing='ij')

patch = vr_slice[iph1:iph2, ith1:ith2]
plt.sca(ax5)
plt.pcolormesh(llons, llats, patch, cmap=plt.cm.RdYlBu_r, vmin=my_min, vmax=my_max, norm=MidpointNormalize(0))
plt.plot(lonvals, np.zeros_like(lonvals), 'k', linewidth=lw)
plt.plot(np.zeros_like(latvals), latvals, 'k', linewidth=lw)
# Get ticks everywhere
plt.minorticks_on()
plt.tick_params(top=True, right=True, direction='in', which='both')
plt.text(-6, 0, 'A', fontsize=ls,\
        horizontalalignment='center', verticalalignment='center')
plt.text(9, -4, 'B', fontsize=ls,\
        horizontalalignment='center', verticalalignment='center')
plt.gca().get_xaxis().set_ticks(xtickvals)
plt.gca().get_yaxis().set_ticks(ytickvals)
#plt.xlabel('longitude (degrees)', fontsize=fs)

t6 = a6.time[0]
vr_slice = a6.vals[:, :, idepth3, a6.lut[1], 0]/100

lon0 = 5*delta_phi_deflection_deg
iph1, iph2 = np.argmin(np.abs(lons - (lon0 - delta_lon/2))),\
    np.argmin(np.abs(lons - (lon0 + delta_lon/2)))
iph1, iph2 = np.argmin(np.abs(lons - (lon0 - delta_lon/2))),\
    np.argmin(np.abs(lons - (lon0 + delta_lon/2)))
lonvals = lons[iph1:iph2] - lon0
llons, llats = np.meshgrid(lonvals, latvals, indexing='ij')

patch = vr_slice[iph1:iph2, ith1:ith2]
plt.sca(ax6)
plt.pcolormesh(llons, llats, patch, cmap=plt.cm.RdYlBu_r, vmin=my_min, vmax=my_max, norm=MidpointNormalize(0))
plt.plot(lonvals, np.zeros_like(lonvals), 'k', linewidth=lw)
plt.plot(np.zeros_like(latvals), latvals, 'k', linewidth=lw)
# Get ticks everywhere
plt.minorticks_on()
plt.tick_params(top=True, right=True, direction='in', which='both')
plt.text(-9, 0, 'A', fontsize=ls,\
        horizontalalignment='center', verticalalignment='center')
plt.text(9, -4, 'B', fontsize=ls,\
        horizontalalignment='center', verticalalignment='center')
plt.text(-9, 16, 'C', fontsize=ls,\
        horizontalalignment='center', verticalalignment='center')
plt.text(-1, 0, 'D', fontsize=ls,\
        horizontalalignment='center', verticalalignment='center')
plt.gca().get_xaxis().set_ticks(xtickvals)
plt.gca().get_yaxis().set_ticks(ytickvals)
#plt.xlabel('longitude (degrees)', fontsize=fs)

t7 = a7.time[0]
vr_slice = a7.vals[:, :, idepth3, a7.lut[1], 0]/100

lon0 = 6*delta_phi_deflection_deg
iph1, iph2 = np.argmin(np.abs(lons - (lon0 - delta_lon/2))),\
    np.argmin(np.abs(lons - (lon0 + delta_lon/2)))
iph1, iph2 = np.argmin(np.abs(lons - (lon0 - delta_lon/2))),\
    np.argmin(np.abs(lons - (lon0 + delta_lon/2)))
lonvals = lons[iph1:iph2] - lon0
llons, llats = np.meshgrid(lonvals, latvals, indexing='ij')

patch = vr_slice[iph1:iph2, ith1:ith2]
plt.sca(ax7)
plt.pcolormesh(llons, llats, patch, cmap=plt.cm.RdYlBu_r, vmin=my_min, vmax=my_max, norm=MidpointNormalize(0))
plt.plot(lonvals, np.zeros_like(lonvals), 'k', linewidth=lw)
plt.plot(np.zeros_like(latvals), latvals, 'k', linewidth=lw)
# Get ticks everywhere
plt.minorticks_on()
plt.tick_params(top=True, right=True, direction='in', which='both')
plt.text(-8, 0, 'A', fontsize=ls,\
        horizontalalignment='center', verticalalignment='center')
plt.text(9, -4, 'B', fontsize=ls,\
        horizontalalignment='center', verticalalignment='center')
plt.text(-10, 16, 'C', fontsize=ls,\
        horizontalalignment='center', verticalalignment='center')
plt.text(-1, 0, 'D', fontsize=ls,\
        horizontalalignment='center', verticalalignment='center')
plt.gca().get_xaxis().set_ticks(xtickvals)
plt.gca().get_yaxis().set_ticks(ytickvals)
#plt.xlabel('longitude (degrees)', fontsize=fs)

t8 = a8.time[0]
vr_slice = a8.vals[:, :, idepth3, a8.lut[1], 0]/100

lon0 = 7*delta_phi_deflection_deg
iph1, iph2 = np.argmin(np.abs(lons - (lon0 - delta_lon/2))),\
    np.argmin(np.abs(lons - (lon0 + delta_lon/2)))
iph1, iph2 = np.argmin(np.abs(lons - (lon0 - delta_lon/2))),\
    np.argmin(np.abs(lons - (lon0 + delta_lon/2)))
lonvals = lons[iph1:iph2] - lon0
llons, llats = np.meshgrid(lonvals, latvals, indexing='ij')

patch = vr_slice[iph1:iph2, ith1:ith2]
plt.sca(ax8)
plt.pcolormesh(llons, llats, patch, cmap=plt.cm.RdYlBu_r, vmin=my_min, vmax=my_max, norm=MidpointNormalize(0))
plt.xlim((-20, 20))
plt.plot(lonvals, np.zeros_like(lonvals), 'k', linewidth=lw)
plt.plot(np.zeros_like(latvals), latvals, 'k', linewidth=lw)
# Get ticks everywhere
plt.minorticks_on()
plt.tick_params(top=True, right=True, direction='in', which='both')
plt.text(-7, 0, 'A', fontsize=ls,\
        horizontalalignment='center', verticalalignment='center')
plt.text(10, -4, 'B', fontsize=ls,\
        horizontalalignment='center', verticalalignment='center')
plt.text(-11, 16, 'C', fontsize=ls,\
        horizontalalignment='center', verticalalignment='center')
plt.text(-1, 0, 'D', fontsize=ls,\
        horizontalalignment='center', verticalalignment='center')
plt.gca().get_yaxis().set_ticks(ytickvals)
#plt.xlabel('longitude (degrees)', fontsize=fs)


cbar=plt.colorbar(cax=cbaxes)
cbar.set_ticks([my_min, 0, my_max])
cbar.ax.set_title('m/s', pad=10, horizontalalignment='left')

ax1.xaxis.set_ticklabels([])
ax2.xaxis.set_ticklabels([])
ax3.xaxis.set_ticklabels([])
ax4.xaxis.set_ticklabels([])

ax2.yaxis.set_ticklabels([])
ax3.yaxis.set_ticklabels([])
ax4.yaxis.set_ticklabels([])
ax6.yaxis.set_ticklabels([])
ax7.yaxis.set_ticklabels([])
ax8.yaxis.set_ticklabels([])

ax8.xaxis.set_ticklabels(['-20', '10', '0', '10', '20'])

global_middle_x = margin_left + 0.5*(4*subplot_width + 3*margin_middle_x)
global_middle_y = margin_bottom + 0.5*(2*subplot_height + margin_middle_y)
fig.text(0.4*margin_left, global_middle_y, 'latitude [deg]', rotation=90,\
         horizontalalignment='right', verticalalignment='center', fontsize=fs)
fig.text(global_middle_x, 0.5*margin_bottom, 'longitude [deg]', \
         horizontalalignment='center', verticalalignment='top', fontsize=fs)
savefile = '/nobackup/lmatilsk/rayleigh/paper_plots/n3_3_patch_evolve.png'
plt.savefig(savefile, dpi=300)
#plt.close()

# %%
print(plotdir)

# %%
fs
